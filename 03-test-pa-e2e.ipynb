# %%
import os

# Define the target directory
target_directory = r"C:\Users\pablosal\Desktop\gbb-ai-hls-factory-prior-auth"  # change your directory here

# Check if the directory exists
if os.path.exists(target_directory):
    # Change the current working directory
    os.chdir(target_directory)
    print(f"Directory changed to {os.getcwd()}")
else:
    print(f"Directory {target_directory} does not exist.")
# Out:
# Directory changed to C:\Users\pablosal\Desktop\gbb-ai-hls-factory-prior-auth

# %%
from src.pipeline.paprocessing.run import PAProcessingPipeline
CASE_ID = "TEST-003b"
pa_pipeline = PAProcessingPipeline(send_cloud_logs=True, caseId=CASE_ID)
# Out:
# 2024-12-28 12:54:41,023 - micro - MainProcess - INFO     Container 'pre-auth-policies' already exists. (blob_helper.py:_create_container_if_not_exists:86)
# C:\Users\pablosal\Desktop\gbb-ai-hls-factory-prior-auth\src\cosmosdb\cosmosmongodb_helper.py:31: UserWarning: You appear to be connected to a CosmosDB cluster. For more information regarding feature compatibility and support please visit https://www.mongodb.com/supportability/cosmosdb
#   self.client = pymongo.MongoClient(connection_string)
# Templates found: ['evaluator_system_prompt.jinja', 'evaluator_user_prompt.jinja', 'formulator_system_prompt.jinja', 'formulator_user_prompt.jinja', 'ner_clinician_system.jinja', 'ner_clinician_user.jinja', 'ner_patient_system.jinja', 'ner_patient_user.jinja', 'ner_physician_system.jinja', 'ner_physician_user.jinja', 'ner_system_prompt.jinja', 'ner_user_prompt.jinja', 'prior_auth_o1_user_prompt.jinja', 'prior_auth_o1_user_prompt_b.jinja', 'prior_auth_system_prompt.jinja', 'prior_auth_user_prompt.jinja', 'query_classificator_system_prompt.jinja', 'query_classificator_user_prompt.jinja', 'query_expansion_system_prompt.jinja', 'query_expansion_user_prompt.jinja', 'summarize_policy_system.jinja', 'summarize_policy_user.jinja']

# %%
uploaded_files = (
    r"C:\Users\pablosal\Desktop\gbb-ai-hls-factory-prior-auth\utils\data\cases\003\b"
)
from src.pipeline.paprocessing.utils import find_all_files

files = find_all_files(uploaded_files, ["pdf"])
# Out:
# 2024-12-28 12:54:41,700 - micro - MainProcess - INFO     Found 3 files with extensions ['pdf'] (utils.py:find_all_files:31)

# %% [markdown]
# ## Testing PA Case

# %%
await pa_pipeline.run(uploaded_files=files, use_o1=True)
# Out:
# 2024-12-28 12:54:41,727 - PAProcessing - MainProcess - INFO     PAProcessing started TEST-003b. (run.py:run:486)
# 2024-12-28 12:54:41,847 - micro - MainProcess - INFO     File 'C:\Users\pablosal\Desktop\gbb-ai-hls-factory-prior-auth\utils\data\cases\003\b\doctor_notes\003_b (note) .pdf' uploaded to blob 'pa_proccesing_runs/TEST-003b/raw_uploaded_files/003_b (note) .pdf' successfully. (blob_helper.py:_upload_single_file:198)
# 2024-12-28 12:54:41,849 - PAProcessing - MainProcess - INFO     Uploaded file 'C:\Users\pablosal\Desktop\gbb-ai-hls-factory-prior-auth\utils\data\cases\003\b\doctor_notes\003_b (note) .pdf' to blob 'https://storageaeastusfactory.blob.core.windows.net/pre-auth-policies/pa_proccesing_runs/TEST-003b/raw_uploaded_files/003_b (note) .pdf' in container 'pre-auth-policies'. (run.py:upload_files_to_blob:253)
# 2024-12-28 12:54:41,902 - micro - MainProcess - INFO     File 'C:\Users\pablosal\Desktop\gbb-ai-hls-factory-prior-auth\utils\data\cases\003\b\labs\003_b (labs) .pdf' uploaded to blob 'pa_proccesing_runs/TEST-003b/raw_uploaded_files/003_b (labs) .pdf' successfully. (blob_helper.py:_upload_single_file:198)
# 2024-12-28 12:54:41,904 - PAProcessing - MainProcess - INFO     Uploaded file 'C:\Users\pablosal\Desktop\gbb-ai-hls-factory-prior-auth\utils\data\cases\003\b\labs\003_b (labs) .pdf' to blob 'https://storageaeastusfactory.blob.core.windows.net/pre-auth-policies/pa_proccesing_runs/TEST-003b/raw_uploaded_files/003_b (labs) .pdf' in container 'pre-auth-policies'. (run.py:upload_files_to_blob:253)
# 2024-12-28 12:54:42,016 - micro - MainProcess - INFO     File 'C:\Users\pablosal\Desktop\gbb-ai-hls-factory-prior-auth\utils\data\cases\003\b\pa_form\003_b (form).pdf' uploaded to blob 'pa_proccesing_runs/TEST-003b/raw_uploaded_files/003_b (form).pdf' successfully. (blob_helper.py:_upload_single_file:198)
# 2024-12-28 12:54:42,018 - PAProcessing - MainProcess - INFO     Uploaded file 'C:\Users\pablosal\Desktop\gbb-ai-hls-factory-prior-auth\utils\data\cases\003\b\pa_form\003_b (form).pdf' to blob 'https://storageaeastusfactory.blob.core.windows.net/pre-auth-policies/pa_proccesing_runs/TEST-003b/raw_uploaded_files/003_b (form).pdf' in container 'pre-auth-policies'. (run.py:upload_files_to_blob:253)
# 2024-12-28 12:54:42,021 - PAProcessing - MainProcess - INFO     All files processed for upload to Azure Blob Storage in container 'pre-auth-policies'. (run.py:upload_files_to_blob:263)
# 2024-12-28 12:54:42,170 - micro - MainProcess - INFO     Container 'pre-auth-policies' already exists. (blob_helper.py:_create_container_if_not_exists:86)
# 2024-12-28 12:54:42,171 - micro - MainProcess - INFO     AzureBlobManager initialized successfully. (pdfhandler.py:__init__:42)
# 2024-12-28 12:54:42,172 - PAProcessing - MainProcess - INFO     Processing file: C:\Users\pablosal\Desktop\gbb-ai-hls-factory-prior-auth\utils\data\cases\003\b\doctor_notes\003_b (note) .pdf (run.py:process_uploaded_files:286)
# 2024-12-28 12:54:42,174 - micro - MainProcess - INFO     Input path is a local file or directory: C:\Users\pablosal\Desktop\gbb-ai-hls-factory-prior-auth\utils\data\cases\003\b\doctor_notes\003_b (note) .pdf (pdfhandler.py:extract_images_from_pdf:101)
# 2024-12-28 12:54:42,178 - micro - MainProcess - INFO     Opening file: C:\Users\pablosal\Desktop\gbb-ai-hls-factory-prior-auth\utils\data\cases\003\b\doctor_notes\003_b (note) .pdf (pdfhandler.py:_process_single_pdf:230)
# 2024-12-28 12:54:42,205 - micro - MainProcess - INFO     Processing page 1 of 'C:\Users\pablosal\Desktop\gbb-ai-hls-factory-prior-auth\utils\data\cases\003\b\doctor_notes\003_b (note) .pdf' (pdfhandler.py:_process_single_pdf:235)
# 2024-12-28 12:54:42,293 - micro - MainProcess - INFO     Saved image: C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12\003_b (note) -page-1.png (pdfhandler.py:_process_single_pdf:243)
# 2024-12-28 12:54:42,294 - micro - MainProcess - INFO     Processing page 2 of 'C:\Users\pablosal\Desktop\gbb-ai-hls-factory-prior-auth\utils\data\cases\003\b\doctor_notes\003_b (note) .pdf' (pdfhandler.py:_process_single_pdf:235)
# 2024-12-28 12:54:42,395 - micro - MainProcess - INFO     Saved image: C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12\003_b (note) -page-2.png (pdfhandler.py:_process_single_pdf:243)
# 2024-12-28 12:54:42,397 - micro - MainProcess - INFO     Processing page 3 of 'C:\Users\pablosal\Desktop\gbb-ai-hls-factory-prior-auth\utils\data\cases\003\b\doctor_notes\003_b (note) .pdf' (pdfhandler.py:_process_single_pdf:235)
# 2024-12-28 12:54:42,495 - micro - MainProcess - INFO     Saved image: C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12\003_b (note) -page-3.png (pdfhandler.py:_process_single_pdf:243)
# 2024-12-28 12:54:42,499 - micro - MainProcess - INFO     Processing page 4 of 'C:\Users\pablosal\Desktop\gbb-ai-hls-factory-prior-auth\utils\data\cases\003\b\doctor_notes\003_b (note) .pdf' (pdfhandler.py:_process_single_pdf:235)
# 2024-12-28 12:54:42,555 - micro - MainProcess - INFO     Saved image: C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12\003_b (note) -page-4.png (pdfhandler.py:_process_single_pdf:243)
# 2024-12-28 12:54:42,644 - micro - MainProcess - INFO     File 'C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12\003_b (note) -page-1.png' uploaded to blob 'pa_proccesing_runs/TEST-003b/processed_images/003_b (note) -page-1.png' successfully. (blob_helper.py:_upload_single_file:198)
# 2024-12-28 12:54:42,646 - PAProcessing - MainProcess - INFO     Uploaded file 'C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12\003_b (note) -page-1.png' to blob 'https://storageaeastusfactory.blob.core.windows.net/pre-auth-policies/pa_proccesing_runs/TEST-003b/processed_images/003_b (note) -page-1.png' in container 'pre-auth-policies'. (run.py:upload_files_to_blob:253)
# 2024-12-28 12:54:42,736 - micro - MainProcess - INFO     File 'C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12\003_b (note) -page-2.png' uploaded to blob 'pa_proccesing_runs/TEST-003b/processed_images/003_b (note) -page-2.png' successfully. (blob_helper.py:_upload_single_file:198)
# 2024-12-28 12:54:42,739 - PAProcessing - MainProcess - INFO     Uploaded file 'C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12\003_b (note) -page-2.png' to blob 'https://storageaeastusfactory.blob.core.windows.net/pre-auth-policies/pa_proccesing_runs/TEST-003b/processed_images/003_b (note) -page-2.png' in container 'pre-auth-policies'. (run.py:upload_files_to_blob:253)
# 2024-12-28 12:54:42,827 - micro - MainProcess - INFO     File 'C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12\003_b (note) -page-3.png' uploaded to blob 'pa_proccesing_runs/TEST-003b/processed_images/003_b (note) -page-3.png' successfully. (blob_helper.py:_upload_single_file:198)
# 2024-12-28 12:54:42,828 - PAProcessing - MainProcess - INFO     Uploaded file 'C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12\003_b (note) -page-3.png' to blob 'https://storageaeastusfactory.blob.core.windows.net/pre-auth-policies/pa_proccesing_runs/TEST-003b/processed_images/003_b (note) -page-3.png' in container 'pre-auth-policies'. (run.py:upload_files_to_blob:253)
# 2024-12-28 12:54:42,889 - micro - MainProcess - INFO     File 'C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12\003_b (note) -page-4.png' uploaded to blob 'pa_proccesing_runs/TEST-003b/processed_images/003_b (note) -page-4.png' successfully. (blob_helper.py:_upload_single_file:198)
# 2024-12-28 12:54:42,890 - PAProcessing - MainProcess - INFO     Uploaded file 'C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12\003_b (note) -page-4.png' to blob 'https://storageaeastusfactory.blob.core.windows.net/pre-auth-policies/pa_proccesing_runs/TEST-003b/processed_images/003_b (note) -page-4.png' in container 'pre-auth-policies'. (run.py:upload_files_to_blob:253)
# 2024-12-28 12:54:42,892 - PAProcessing - MainProcess - INFO     All files processed for upload to Azure Blob Storage in container 'pre-auth-policies'. (run.py:upload_files_to_blob:263)
# 2024-12-28 12:54:42,893 - PAProcessing - MainProcess - INFO     Images extracted and uploaded from: C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12 (run.py:process_uploaded_files:296)
# 2024-12-28 12:54:42,894 - PAProcessing - MainProcess - INFO     Processing file: C:\Users\pablosal\Desktop\gbb-ai-hls-factory-prior-auth\utils\data\cases\003\b\labs\003_b (labs) .pdf (run.py:process_uploaded_files:286)
# 2024-12-28 12:54:42,896 - micro - MainProcess - INFO     Input path is a local file or directory: C:\Users\pablosal\Desktop\gbb-ai-hls-factory-prior-auth\utils\data\cases\003\b\labs\003_b (labs) .pdf (pdfhandler.py:extract_images_from_pdf:101)
# 2024-12-28 12:54:42,899 - micro - MainProcess - INFO     Opening file: C:\Users\pablosal\Desktop\gbb-ai-hls-factory-prior-auth\utils\data\cases\003\b\labs\003_b (labs) .pdf (pdfhandler.py:_process_single_pdf:230)
# 2024-12-28 12:54:42,905 - micro - MainProcess - INFO     Processing page 1 of 'C:\Users\pablosal\Desktop\gbb-ai-hls-factory-prior-auth\utils\data\cases\003\b\labs\003_b (labs) .pdf' (pdfhandler.py:_process_single_pdf:235)
# 2024-12-28 12:54:42,972 - micro - MainProcess - INFO     Saved image: C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12\003_b (labs) -page-1.png (pdfhandler.py:_process_single_pdf:243)
# 2024-12-28 12:54:42,974 - micro - MainProcess - INFO     Processing page 2 of 'C:\Users\pablosal\Desktop\gbb-ai-hls-factory-prior-auth\utils\data\cases\003\b\labs\003_b (labs) .pdf' (pdfhandler.py:_process_single_pdf:235)
# 2024-12-28 12:54:43,051 - micro - MainProcess - INFO     Saved image: C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12\003_b (labs) -page-2.png (pdfhandler.py:_process_single_pdf:243)
# 2024-12-28 12:54:43,052 - micro - MainProcess - INFO     Processing page 3 of 'C:\Users\pablosal\Desktop\gbb-ai-hls-factory-prior-auth\utils\data\cases\003\b\labs\003_b (labs) .pdf' (pdfhandler.py:_process_single_pdf:235)
# 2024-12-28 12:54:43,124 - micro - MainProcess - INFO     Saved image: C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12\003_b (labs) -page-3.png (pdfhandler.py:_process_single_pdf:243)
# 2024-12-28 12:54:43,218 - micro - MainProcess - INFO     File 'C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12\003_b (labs) -page-1.png' uploaded to blob 'pa_proccesing_runs/TEST-003b/processed_images/003_b (labs) -page-1.png' successfully. (blob_helper.py:_upload_single_file:198)
# 2024-12-28 12:54:43,221 - PAProcessing - MainProcess - INFO     Uploaded file 'C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12\003_b (labs) -page-1.png' to blob 'https://storageaeastusfactory.blob.core.windows.net/pre-auth-policies/pa_proccesing_runs/TEST-003b/processed_images/003_b (labs) -page-1.png' in container 'pre-auth-policies'. (run.py:upload_files_to_blob:253)
# 2024-12-28 12:54:43,311 - micro - MainProcess - INFO     File 'C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12\003_b (labs) -page-2.png' uploaded to blob 'pa_proccesing_runs/TEST-003b/processed_images/003_b (labs) -page-2.png' successfully. (blob_helper.py:_upload_single_file:198)
# 2024-12-28 12:54:43,312 - PAProcessing - MainProcess - INFO     Uploaded file 'C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12\003_b (labs) -page-2.png' to blob 'https://storageaeastusfactory.blob.core.windows.net/pre-auth-policies/pa_proccesing_runs/TEST-003b/processed_images/003_b (labs) -page-2.png' in container 'pre-auth-policies'. (run.py:upload_files_to_blob:253)
# 2024-12-28 12:54:43,393 - micro - MainProcess - INFO     File 'C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12\003_b (labs) -page-3.png' uploaded to blob 'pa_proccesing_runs/TEST-003b/processed_images/003_b (labs) -page-3.png' successfully. (blob_helper.py:_upload_single_file:198)
# 2024-12-28 12:54:43,394 - PAProcessing - MainProcess - INFO     Uploaded file 'C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12\003_b (labs) -page-3.png' to blob 'https://storageaeastusfactory.blob.core.windows.net/pre-auth-policies/pa_proccesing_runs/TEST-003b/processed_images/003_b (labs) -page-3.png' in container 'pre-auth-policies'. (run.py:upload_files_to_blob:253)
# 2024-12-28 12:54:43,395 - PAProcessing - MainProcess - INFO     All files processed for upload to Azure Blob Storage in container 'pre-auth-policies'. (run.py:upload_files_to_blob:263)
# 2024-12-28 12:54:43,398 - PAProcessing - MainProcess - INFO     Images extracted and uploaded from: C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12 (run.py:process_uploaded_files:296)
# 2024-12-28 12:54:43,404 - PAProcessing - MainProcess - INFO     Processing file: C:\Users\pablosal\Desktop\gbb-ai-hls-factory-prior-auth\utils\data\cases\003\b\pa_form\003_b (form).pdf (run.py:process_uploaded_files:286)
# 2024-12-28 12:54:43,406 - micro - MainProcess - INFO     Input path is a local file or directory: C:\Users\pablosal\Desktop\gbb-ai-hls-factory-prior-auth\utils\data\cases\003\b\pa_form\003_b (form).pdf (pdfhandler.py:extract_images_from_pdf:101)
# 2024-12-28 12:54:43,406 - micro - MainProcess - INFO     Opening file: C:\Users\pablosal\Desktop\gbb-ai-hls-factory-prior-auth\utils\data\cases\003\b\pa_form\003_b (form).pdf (pdfhandler.py:_process_single_pdf:230)
# 2024-12-28 12:54:43,417 - micro - MainProcess - INFO     Processing page 1 of 'C:\Users\pablosal\Desktop\gbb-ai-hls-factory-prior-auth\utils\data\cases\003\b\pa_form\003_b (form).pdf' (pdfhandler.py:_process_single_pdf:235)
# 2024-12-28 12:54:43,514 - micro - MainProcess - INFO     Saved image: C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12\003_b (form)-page-1.png (pdfhandler.py:_process_single_pdf:243)
# 2024-12-28 12:54:43,518 - micro - MainProcess - INFO     Processing page 2 of 'C:\Users\pablosal\Desktop\gbb-ai-hls-factory-prior-auth\utils\data\cases\003\b\pa_form\003_b (form).pdf' (pdfhandler.py:_process_single_pdf:235)
# 2024-12-28 12:54:43,614 - micro - MainProcess - INFO     Saved image: C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12\003_b (form)-page-2.png (pdfhandler.py:_process_single_pdf:243)
# 2024-12-28 12:54:43,739 - micro - MainProcess - INFO     File 'C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12\003_b (form)-page-1.png' uploaded to blob 'pa_proccesing_runs/TEST-003b/processed_images/003_b (form)-page-1.png' successfully. (blob_helper.py:_upload_single_file:198)
# 2024-12-28 12:54:43,742 - PAProcessing - MainProcess - INFO     Uploaded file 'C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12\003_b (form)-page-1.png' to blob 'https://storageaeastusfactory.blob.core.windows.net/pre-auth-policies/pa_proccesing_runs/TEST-003b/processed_images/003_b (form)-page-1.png' in container 'pre-auth-policies'. (run.py:upload_files_to_blob:253)
# 2024-12-28 12:54:43,844 - micro - MainProcess - INFO     File 'C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12\003_b (form)-page-2.png' uploaded to blob 'pa_proccesing_runs/TEST-003b/processed_images/003_b (form)-page-2.png' successfully. (blob_helper.py:_upload_single_file:198)
# 2024-12-28 12:54:43,844 - PAProcessing - MainProcess - INFO     Uploaded file 'C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12\003_b (form)-page-2.png' to blob 'https://storageaeastusfactory.blob.core.windows.net/pre-auth-policies/pa_proccesing_runs/TEST-003b/processed_images/003_b (form)-page-2.png' in container 'pre-auth-policies'. (run.py:upload_files_to_blob:253)
# 2024-12-28 12:54:43,846 - PAProcessing - MainProcess - INFO     All files processed for upload to Azure Blob Storage in container 'pre-auth-policies'. (run.py:upload_files_to_blob:263)
# 2024-12-28 12:54:43,851 - PAProcessing - MainProcess - INFO     Images extracted and uploaded from: C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12 (run.py:process_uploaded_files:296)
# 2024-12-28 12:54:43,854 - PAProcessing - MainProcess - INFO     Files processed and images extracted to: C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12 (run.py:process_uploaded_files:298)
# 2024-12-28 12:54:43,861 - micro - MainProcess - INFO     Found 9 files with extensions ['png'] (utils.py:find_all_files:31)
# 2024-12-28 12:54:43,863 - extractionLLM - MainProcess - INFO     [caseID: TEST-003b]
# Extracting patient data... (run.py:extract_patient_data:125)
# 2024-12-28 12:54:43,871 - micro - MainProcess - INFO     Function generate_chat_response started at 2024-12-28 12:54:43 (aoai_helper.py:generate_chat_response:370)
# 2024-12-28 12:54:43,875 - micro - MainProcess - INFO     Image C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12\003_b (form)-page-1.png type: image/png (aoai_helper.py:generate_chat_response:413)
# 2024-12-28 12:54:43,879 - micro - MainProcess - INFO     Image C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12\003_b (form)-page-2.png type: image/png (aoai_helper.py:generate_chat_response:413)
# 2024-12-28 12:54:43,886 - micro - MainProcess - INFO     Image C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12\003_b (labs) -page-1.png type: image/png (aoai_helper.py:generate_chat_response:413)
# 2024-12-28 12:54:43,891 - micro - MainProcess - INFO     Image C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12\003_b (labs) -page-2.png type: image/png (aoai_helper.py:generate_chat_response:413)
# 2024-12-28 12:54:43,955 - micro - MainProcess - INFO     Image C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12\003_b (labs) -page-3.png type: image/png (aoai_helper.py:generate_chat_response:413)
# 2024-12-28 12:54:43,971 - micro - MainProcess - INFO     Image C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12\003_b (note) -page-1.png type: image/png (aoai_helper.py:generate_chat_response:413)
# 2024-12-28 12:54:43,976 - micro - MainProcess - INFO     Image C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12\003_b (note) -page-2.png type: image/png (aoai_helper.py:generate_chat_response:413)
# 2024-12-28 12:54:43,981 - micro - MainProcess - INFO     Image C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12\003_b (note) -page-3.png type: image/png (aoai_helper.py:generate_chat_response:413)
# 2024-12-28 12:54:43,984 - micro - MainProcess - INFO     Image C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12\003_b (note) -page-4.png type: image/png (aoai_helper.py:generate_chat_response:413)
# 2024-12-28 12:54:43,987 - micro - MainProcess - INFO     Sending request to Azure OpenAI at 2024-12-28 12:54:43 (aoai_helper.py:generate_chat_response:427)
# 2024-12-28 12:54:49,345 - micro - MainProcess - INFO     Function generate_chat_response finished at 2024-12-28 12:54:49 (Duration: 5.47 seconds) (aoai_helper.py:generate_chat_response:481)
# 2024-12-28 12:54:49,350 - extractionLLM - MainProcess - INFO     [caseID: TEST-003b]
# Extracting physician data... (run.py:extract_physician_data:172)
# 2024-12-28 12:54:49,355 - micro - MainProcess - INFO     Function generate_chat_response started at 2024-12-28 12:54:49 (aoai_helper.py:generate_chat_response:370)
# 2024-12-28 12:54:49,359 - micro - MainProcess - INFO     Image C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12\003_b (form)-page-1.png type: image/png (aoai_helper.py:generate_chat_response:413)
# 2024-12-28 12:54:49,364 - micro - MainProcess - INFO     Image C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12\003_b (form)-page-2.png type: image/png (aoai_helper.py:generate_chat_response:413)
# 2024-12-28 12:54:49,369 - micro - MainProcess - INFO     Image C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12\003_b (labs) -page-1.png type: image/png (aoai_helper.py:generate_chat_response:413)
# 2024-12-28 12:54:49,374 - micro - MainProcess - INFO     Image C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12\003_b (labs) -page-2.png type: image/png (aoai_helper.py:generate_chat_response:413)
# 2024-12-28 12:54:49,378 - micro - MainProcess - INFO     Image C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12\003_b (labs) -page-3.png type: image/png (aoai_helper.py:generate_chat_response:413)
# 2024-12-28 12:54:49,383 - micro - MainProcess - INFO     Image C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12\003_b (note) -page-1.png type: image/png (aoai_helper.py:generate_chat_response:413)
# 2024-12-28 12:54:49,388 - micro - MainProcess - INFO     Image C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12\003_b (note) -page-2.png type: image/png (aoai_helper.py:generate_chat_response:413)
# 2024-12-28 12:54:49,391 - micro - MainProcess - INFO     Image C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12\003_b (note) -page-3.png type: image/png (aoai_helper.py:generate_chat_response:413)
# 2024-12-28 12:54:49,394 - micro - MainProcess - INFO     Image C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12\003_b (note) -page-4.png type: image/png (aoai_helper.py:generate_chat_response:413)
# 2024-12-28 12:54:49,396 - micro - MainProcess - INFO     Sending request to Azure OpenAI at 2024-12-28 12:54:49 (aoai_helper.py:generate_chat_response:427)
# 2024-12-28 12:54:54,279 - micro - MainProcess - INFO     Function generate_chat_response finished at 2024-12-28 12:54:54 (Duration: 4.92 seconds) (aoai_helper.py:generate_chat_response:481)
# 2024-12-28 12:54:54,290 - extractionLLM - MainProcess - INFO     [caseID: TEST-003b]
# Extracting clinician data... (run.py:extract_clinician_data:218)
# 2024-12-28 12:54:54,297 - micro - MainProcess - INFO     Function generate_chat_response started at 2024-12-28 12:54:54 (aoai_helper.py:generate_chat_response:370)
# 2024-12-28 12:54:54,306 - micro - MainProcess - INFO     Image C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12\003_b (form)-page-1.png type: image/png (aoai_helper.py:generate_chat_response:413)
# 2024-12-28 12:54:54,313 - micro - MainProcess - INFO     Image C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12\003_b (form)-page-2.png type: image/png (aoai_helper.py:generate_chat_response:413)
# 2024-12-28 12:54:54,321 - micro - MainProcess - INFO     Image C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12\003_b (labs) -page-1.png type: image/png (aoai_helper.py:generate_chat_response:413)
# 2024-12-28 12:54:54,326 - micro - MainProcess - INFO     Image C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12\003_b (labs) -page-2.png type: image/png (aoai_helper.py:generate_chat_response:413)
# 2024-12-28 12:54:54,331 - micro - MainProcess - INFO     Image C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12\003_b (labs) -page-3.png type: image/png (aoai_helper.py:generate_chat_response:413)
# 2024-12-28 12:54:54,339 - micro - MainProcess - INFO     Image C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12\003_b (note) -page-1.png type: image/png (aoai_helper.py:generate_chat_response:413)
# 2024-12-28 12:54:54,344 - micro - MainProcess - INFO     Image C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12\003_b (note) -page-2.png type: image/png (aoai_helper.py:generate_chat_response:413)
# 2024-12-28 12:54:54,354 - micro - MainProcess - INFO     Image C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12\003_b (note) -page-3.png type: image/png (aoai_helper.py:generate_chat_response:413)
# 2024-12-28 12:54:54,357 - micro - MainProcess - INFO     Image C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12\003_b (note) -page-4.png type: image/png (aoai_helper.py:generate_chat_response:413)
# 2024-12-28 12:54:54,360 - micro - MainProcess - INFO     Sending request to Azure OpenAI at 2024-12-28 12:54:54 (aoai_helper.py:generate_chat_response:427)
# 2024-12-28 12:55:04,704 - micro - MainProcess - INFO     Function generate_chat_response finished at 2024-12-28 12:55:04 (Duration: 10.41 seconds) (aoai_helper.py:generate_chat_response:481)
# 2024-12-28 12:55:04,721 - PAProcessing - MainProcess - DEBUG    Data logged for case 'TEST-003b' at step 'ocr_ner_extraction'. (run.py:log_output:377)
# 2024-12-28 12:55:04,725 - agenticRag - MainProcess - INFO     [caseID: TEST-003b] Starting AgenticRAG attempt 1 of 3 (run.py:run:290)
# 2024-12-28 12:55:04,728 - agenticRag - MainProcess - INFO     [caseID: TEST-003b] Expanding query... (run.py:expand_query:101)
# 2024-12-28 12:55:04,744 - micro - MainProcess - INFO     Function generate_chat_response started at 2024-12-28 12:55:04 (aoai_helper.py:generate_chat_response:370)
# 2024-12-28 12:55:04,745 - micro - MainProcess - INFO     Sending request to Azure OpenAI at 2024-12-28 12:55:04 (aoai_helper.py:generate_chat_response:427)
# 2024-12-28 12:55:06,248 - micro - MainProcess - INFO     Function generate_chat_response finished at 2024-12-28 12:55:06 (Duration: 1.50 seconds) (aoai_helper.py:generate_chat_response:481)
# 2024-12-28 12:55:06,250 - agenticRag - MainProcess - INFO     [caseID: TEST-003b] Expanded Query: Prior authorization policy for Blinatumomab for B-cell precursor acute lymphoblastic leukemia (B-ALL). Related terms: Philadelphia chromosome-positive B-cell precursor acute lymphoblastic leukemia, Ph+ B-ALL, relapsed B-ALL, refractory B-ALL, post-consolidation phase treatment, CD19-targeted therapy, BiTE (bispecific T-cell engager) therapy. Dosage details: 28 mcg/day, induction cycle 1: Days 1-28: 28 mcg/day, with potential treatment duration up to 6 months based on clinical response. Rationale: Management of relapsed or refractory B-ALL and prevention of disease progression. (run.py:run:298)
# 2024-12-28 12:55:06,253 - agenticRag - MainProcess - INFO     [caseID: TEST-003b] Retrieving policies... (run.py:retrieve_policies:200)
# 2024-12-28 12:55:06,790 - agenticRag - MainProcess - INFO     [caseID: TEST-003b] Search results retrieved successfully (run.py:run:306)
# 2024-12-28 12:55:06,794 - agenticRag - MainProcess - INFO     [caseID: TEST-003b] Evaluating search results... (run.py:evaluate_results:246)
# 2024-12-28 12:55:06,806 - micro - MainProcess - INFO     Function generate_chat_response started at 2024-12-28 12:55:06 (aoai_helper.py:generate_chat_response:370)
# 2024-12-28 12:55:06,807 - micro - MainProcess - INFO     Sending request to Azure OpenAI at 2024-12-28 12:55:06 (aoai_helper.py:generate_chat_response:427)
# 2024-12-28 12:55:08,387 - micro - MainProcess - INFO     Function generate_chat_response finished at 2024-12-28 12:55:08 (Duration: 1.58 seconds) (aoai_helper.py:generate_chat_response:481)
# 2024-12-28 12:55:08,390 - agenticRag - MainProcess - INFO     [caseID: TEST-003b] /n Evaluation response:
#                          {'policies': ['https://storageaeastusfactory.blob.core.windows.net/pre-auth-policies/policies_ocr/003.pdf'], 'reasoning': ["Content from https://storageaeastusfactory.blob.core.windows.net/pre-auth-policies/policies_ocr/003.pdf was approved because it explicitly mentioned prior authorization criteria for Blinatumomab (Blincyto) in treating B-cell precursor acute lymphoblastic leukemia (B-ALL), including both relapsed and refractory cases, and provided detailed dosage information matching the user's query."], 'retry': False} (run.py:evaluate_results:268)
# 2024-12-28 12:55:08,392 - agenticRag - MainProcess - INFO     [caseID: TEST-003b] Evaluation successful. Policies: ['https://storageaeastusfactory.blob.core.windows.net/pre-auth-policies/policies_ocr/003.pdf'] (run.py:run:311)
# 2024-12-28 12:55:08,685 - micro - MainProcess - INFO     Downloaded blob 'policies_ocr/003.pdf' as bytes. (blob_helper.py:download_blob_to_bytes:308)
# 2024-12-28 12:55:08,688 - PAProcessing - MainProcess - INFO     Blob content downloaded successfully from https://storageaeastusfactory.blob.core.windows.net/pre-auth-policies/policies_ocr/003.pdf (run.py:get_policy_text_from_blob:320)
# 2024-12-28 12:55:16,888 - PAProcessing - MainProcess - INFO     Document analyzed successfully for blob https://storageaeastusfactory.blob.core.windows.net/pre-auth-policies/policies_ocr/003.pdf (run.py:get_policy_text_from_blob:327)
# 2024-12-28 12:55:16,892 - PAProcessing - MainProcess - DEBUG    Data logged for case 'TEST-003b' at step 'policy_search'. (run.py:log_output:377)
# 2024-12-28 12:55:16,901 - autoDetermination - MainProcess - INFO     Generating final determination for TEST-003b (run.py:run:92)
# 2024-12-28 12:55:16,903 - autoDetermination - MainProcess - INFO     Input clinical information: **Task:**
#
# Analyze a prior authorization request for a medical treatment or medication using the provided patient information, physician information, clinical information, and policy text.
#
# ---
#
# **Purpose:**
#
# Determine whether the prior authorization request should be Approved, Denied, or if More Information is Needed.
#
# ---
#
# **Approach:**
#
# - Analyze all policy criteria by thoroughly reviewing the policy text.
# - Extract necessary information from the policy and the provided data.
# - Compare the extracted information from the patient, physician, and clinical data against the policy criteria.
# - Make a detailed decision based on these comparisons.
#
# ---
#
# **Instructions:**
#
# **Analyze Policy Criteria:**
#
# - Carefully read the entire policy text relevant to the requested medication or procedure.
# - Extract and list every key criterion and requirement, including but not limited to:
#   - Specific conditions and diagnoses.
#   - Prior treatment requirements.
#   - Dosage limitations and guidelines.
#   - Patient eligibility criteria.
#   - Physician qualifications.
#   - Required diagnostic tests or lab results.
#   - Exclusions and contraindications.
#   - Authorization duration and renewal criteria.
# - Pay special attention to qualifying statements such as "and," "or," "must," "should," "unless," "except," and "if."
#
# **Extract Necessary Information from Provided Data:**
#
# - From the patient, physician, and clinical information, extract relevant details that correspond to each policy criterion.
# - Ensure no important information is overlooked.
#
# **Compare Information:**
#
# - For each policy criterion, compare it with the extracted data from the patient and clinical information.
# - Indicate whether each criterion is Fully Met, Partially Met, or Not Met.
# - Provide evidence from the data and cite relevant sections of the policy text.
#
# **Identify Gaps or Missing Information:**
#
# - Note any missing details that prevent a full evaluation.
# - Specify additional information required, if any, and explain why it is necessary.
#
# **Make a Detailed Decision:**
#
# - Based on the comprehensive comparison, decide if the request should be Approved, Denied, or if More Information is Needed.
# - Justify the decision with logical reasoning and evidence from the provided information and policy text.
#
# ---
#
# **Decision Criteria:**
#
# - **Approved:** The request meets all the criteria outlined in the policy text.
# - **Denied:** The request does not meet one or more of the criteria outlined in the policy text. If any criterion is not met or only partially met, the request must be denied.
# - **Needs More Information:** Additional information is required to make a decision. Specify what is needed and why. If a specific criterion from the policy text is not demonstrated in the clinical information (such as prior or alternative treatments), assume it is absent and deny the request. If other physician or patient information is unclear or ambiguous, additional information can be requested.
#
# ---
#
# **Patient Information:**
#
# - Patient Name: Lucas Little
# - Date of Birth: 07/30/2017
# - Patient ID: 345987
# - Address: 28 Dearborn St, Chicago, IL, 60602
# - Phone Number: 555-360-8746
#
# ---
#
# **Physician Information:**
#
# - Physician Name: Dr. Oncoso
# - Specialty: Pediatric Hematology and Oncology
# - **Contact Information:**
#   - Office Phone: 555-324-7878
#   - Fax: 555-324-7877
#   - Address: 27 W State St, Chicago, IL 60601
#
# ---
#
# **Clinical Information:**
#
# - Diagnosis: B-cell precursor acute lymphoblastic leukemia (B-ALL), post-consolidation phase treatment; Philadelphia chromosome-positive B-cell precursor acute lymphoblastic leukemia (B-ALL); relapsed or refractory B-ALL
# - ICD-10 Code: C91.00
# - History of Prior Treatments and Results: Induction Phase: Vincristine (weekly), Dexamethasone (daily for 28 days), L-asparaginase (alternate days), Daunorubicin (single dose during first week), Imatinib (daily throughout induction phase); Consolidation Phase: Methotrexate (high-dose, weekly), Mercaptopurine (daily oral), Vincristine (biweekly), Cyclophosphamide (third week), Doxorubicin (final week), Imatinib (daily throughout consolidation); Initial Proposed Maintenance Phase: Methotrexate (weekly), Mercaptopurine (daily oral), Vincristine (every 4 weeks), Imatinib (daily), Intrathecal Methotrexate (every 2-3 months)
# - Specific Drugs Taken and Outcomes: Imatinib: Administered daily throughout induction and consolidation phases; Methotrexate: High-dose, weekly; Mercaptopurine: Daily oral administration; Vincristine: Biweekly; Cyclophosphamide: Given during the third week; Doxorubicin: Administered during the final week of consolidation
# - Alternative Drugs Required: Not provided
# - Lab Results or Diagnostic Imaging: White Blood Cell Count (WBC): 4,500 - 10,000 cells/µL; Neutrophils: 40%; Lymphocytes: 20%; Monocytes: 2%; Eosinophils: 1%; Basophils: 0%; Hemoglobin (Hgb): 11.5 g/dL; Hematocrit (Hct): 35%; Platelet Count: 150,000 cells/µL; Bone Marrow Biopsy (10/4/24): >90% blasts, relapsed or refractory B-ALL; Bone Marrow Biopsy (3/29/24): 85% lymphoblasts, Philadelphia chromosome-positive (Ph+)
# - Symptom Severity and Impact on Daily Life: Fatigue, mild fatigue and decreased energy, no recent fevers
# - Prognosis and Risk if Not Approved: Risk of disease progression and worsening symptoms if treatment is not approved
# - Clinical Rationale for Urgency: Urgent need to prevent disease progression and manage relapsed or refractory B-ALL
#
# ---
#
# **Treatment Plan:**
#
# - Requested Medication or Procedure: Blinatumomab
# - Medication or Procedure Code: Not provided
# - Dosage: 28 mcg/day
# - Duration:
# - Rationale: To manage relapsed or refractory B-ALL and prevent disease progression
# - Presumed Eligibility: Patient has tried and failed previous treatments including Imatinib and standard chemotherapy regimen
#
# ---
#
# **Policy Text:**
#
# <figure>
#
# ![](figures/0)
#
# <!-- FigureContent="envolve. Pharmacy Solutions" -->
#
# </figure>
#
#
# Clinical Policy: Blinatumomab (Blincyto) Reference Number: ERX.SPA.241 Effective Date: 09.01.18 Last Review Date: 08.18
#
# Revision Log
#
# See Important Reminder at the end of this policy for important regulatory and legal information.
#
# Description Blinatumomab (Blincyto®) is a bispecific CD19-directed CD3 T-cell engager that binds to CD19 (expressed on cells of B-lineage origin) and CD3 (expressed on T cells).
#
#
# # FDA Approved Indication(s) Blincyto is indicated for:
#
# • MRD-positive B-cell precursor ALL
#
# o Treatment of B-cell precursor acute lymphoblastic leukemia (ALL) in first or second complete remission with minimal residual disease (MRD) greater than or equal to 0.1% in adults and children. This indication is approved under accelerated approval based on MRD response rate and hematological relapse-free survival. Continued approval for this indication may be contingent upon verification and description of clinical benefit in the confirmatory trials.
#
# · Relapsed or refractory B-cell precursor ALL
#
# o Treatment of relapsed or refractory B-cell precursor acute lymphoblastic leukemia (ALL) in adults and children.
#  :unselected:
# Policy/Criteria
#
# Provider must submit documentation (such as office chart notes, lab results or other clinical information) supporting that member has met all approval criteria.
#
# It is the policy of health plans affiliated with Envolve Pharmacy Solutions™ that Blincyto is medically necessary when the following criteria are met:
#
# I. Initial Approval Criteria
#
# A. Acute Lymphoblastic Leukemia (must meet all):
#
# 1\. Diagnosis of B-cell precursor acute lymphoblastic leukemia (B-ALL);
#
# 2\. Prescribed by or in consultation with an oncologist or hematologist;
#
# 3\. Requested as treatment for (a or b):
#
# a. B-ALL in remission but positive for minimal residual disease (MRD+);
#
# b. Relapsed or refractory B-ALL (i and ii):
#
# i. Philadelphia chromosome-negative (Ph-) disease;
#
# ii. Philadelphia chromosome-positive (Ph+) disease and intolerant or refractory to at least one second-generation or later tyrosine kinase inhibitor (TKI; i.e., Sprycel®, Tasigna®, Bosulif®, Iclusig®);
#
# \*Prior authorization is (or may be) required for these agents
#
# 4\. Dose does not exceed 28 mcg/day. Approval duration: 6 months
#
# B. Other diagnoses/indications
#
# 1\. Refer to ERX.PA.01 if diagnosis is NOT specifically listed under section III
#
# (Diagnoses/Indications for which coverage is NOT authorized).
#
#
# # II. Continued Therapy
#
# A. Acute Lymphoblastic Leukemia (must meet all):
#
# 1\. Currently receiving medication via a health plan affiliated with Envolve Pharmacy Solutions, or documentation supports that member is currently receiving Blincyto for a covered indication and has received this medication for at least 30 days;
#
# 2\. Member is responding positively to therapy;
#
# <!-- PageNumber="Page 1 of 4" -->
#
# <!-- PageHeader="CLINICAL POLICY Blinatumomab" -->
#
# <figure>
#
# ![](figures/1)
#
# <!-- FigureContent="envolve Pharmacy Solutions TM" -->
#
# </figure>
#
#
# 3\. If request is for a dose increase, new dose does not exceed 28 mcg/day. Approval duration: 12 months
#
# B. Other diagnoses/indications (must meet 1 or 2):
#
# 1\. Currently receiving medication via a health plan affiliated with Envolve Pharmacy Solutions and documentation supports positive response to therapy.
#
# Approval duration: Duration of request or 6 months (whichever is less); or
#
# 2\. Refer to ERX.PA.01 if diagnosis is NOT specifically listed under section III (Diagnoses/Indications for which coverage is NOT authorized).
#
# III. Diagnoses/Indications for which coverage is NOT authorized:
#
# A. Non-FDA approved indications, which are not addressed in this policy, unless there is sufficient documentation of efficacy and safety according to the off-label use policy - ERX.PA.01 or evidence of coverage documents.
#
#
# # IV. Appendices/General Information
#
# Appendix A: Abbreviation/Acronym Key B-ALL: B-cell precursor acute lymphoblastic leukemia CR: complete remission
#
# FDA: Food and Drug Administration MRD+: positive minimal residual disease TKI: tyrosine kinase inhibitor
#
# Appendix B: Therapeutic Alternatives This table provides a listing of preferred alternative therapy recommended in the approval criteria. The drugs listed here may not be a formulary agent and may require prior authorization.
#
# | Drug Name | Dosing Regimen | Dose Limit/ Maximum Dose |
# | - | - | - |
# | Sprycel® (dasatinib) | 140 mg PO QD (adults\*) | 180 mg/day |
# | Iclusig® (ponatinib) | 45 mg PO QD (adults\*) | 45 mg/day |
# | Tasigna® (nilotinib) | 400 mg PO BID (off-label use; adults\* - as referenced in Kim, et al., 2015; see also Appendix D) | 800 mg/day |
# | Bosulif® (bosutinib) | 500 to 600 mg PO QD (off-label use; adults\* - as referenced in Gambacroti-Passerini, et al., 2015; see also Appendix D). | 600 mg/day |
#
# Therapeutic alternatives are listed as Brand name® (generic) when the drug is available by brand name only and generic (Brand name®) when the drug is available by both brand and generic.
#
# \*Sprycel and Iclusig are FDA approved for Ph+ ALL in adults; however, all four listed TKIs are NCCN recommended (category 2A) for Ph+ ALL in both adults and adolescents/young adults.
#
# Appendix C: Contraindications Not applicable
#
# Appendix D: General Information
#
# . MRD-positive B-cell precursor ALL
#
# In 2018, Blincyto received FDA approval for MRD+ B-ALL in remission based on a single- o arm, open label study (BLAST) showing complete MRD response in a majority of adults undergoing Blincyto therapy; the new FDA indication includes both children and adults based on this pivotal trial.
#
# o In 2017, blinatumomab's labeled use was expanded from treatment of Ph- relapsed/refractory • Relapsed or refractory B-cell precursor ALL
#
# B-ALL to treatment of Ph+ disease based on a single-arm, open label study (ALCANTARAA) showing complete remission (CR), or CR with partial hematologic recovery, after disease progression on at least one second- or thid-generation TKI. FDA approved second- and third- generation TKIs for Ph+ ALL in adults include Sprycel and Iclusig. NCCN recommended (category 2A) TKIs for Ph+ ALL in adults and adolescents/young adults include Sprycel, Iclusig, Tasigna and Bosulif.
#
# <!-- PageNumber="Page 2 of 4" -->
#
# CLINICAL POLICY Blinatumomab
#
# <figure>
#
# ![](figures/2)
#
# <!-- FigureContent="envolve Pharmacy Solutions TM" -->
#
# </figure>
#
#
#
# # V. Dosage and Administration
#
# | Indication || Dosing Regimen  | Maximum Dose |
# | - | - | - | - |
# | B-ALL (MRD+ in | Treatment course: 1 cycle of Blincyto IV for induction followed by up to 3 additional cycles for consolidation. || 28 mcg/day |
# | remission) | Patients ≥ 45 kg receive a fixed dose • |
# || || o Induction cycle 1 . Days 1-28: 28 mcg/day . Days 29-42: 14-day treatment-free interval
# || || :unselected: :unselected: | o Consolidation cycles 2-4 . Days 1-28: 28 mcg/day . Days 29-42: 14-day treatment-free interval |
# || || Patients < 45 kg based on body surface area (BSA) • |
# || || o :unselected: Induction cycle 1 . Days 1-7: 5 mcg/m2/day |
# |||
# || || || · Days 8-28: 15 mcg/m2/day . Days 29-42: 14-day treatment-free interval |
# |||
# || || || :unselected: o Consolidation cycles 2-4 Days 1-28: 15 mcg/m2/day |
# || || Days 29-42: 14-day treatment-free interval || |
# | B-ALL (relapsed or | Treatment course: 2 cycles of Blincyto IV for induction followed by 3 cycles for consolidation and up to 4 cycles of continued therapy. || 28 mcg/day |
# |||| |
# | refractory) | Patients ≥ 45 kg receive a fixed dose • |
# || || o Induction cycle 1 . Days 1-7: 9 mcg/day . Days 8-28: 28 mcg/day Days 29-42: 14-day treatment-free interval . :unselected: |
# |||
# || || || o Induction cycle 2 :unselected: |
# || || . Days 1-28: 28 mcg/day |
# || || . Days 29-42: 14-day treatment-free interval |
# || || o Consolidation cycles 3-5 . Days 1-28: 28 mcg/day . Days 29-42: 14-day treatment-free interval
# || || :unselected: :unselected: | o Continued therapy cycles 6-9 Days 1-28: 28 mcg/day . · Days 29-84: 56-day treatment-free interval |
# || || Patients < 45 kg based on body surface area (BSA) • o Induction cycle 1 :unselected: . Days 1-7: 5 mcg/m2/day |
# |||
# || || || Days 8-28: 15 mcg/m2/day . |
# || || . Days 29-42: 14-day treatment-free interval |
# || || o Induction cycle 2
# |
# || || . :unselected: || || " Days 1-28: 15 mcg/m2/day | Days 29-42: 14-day treatment-free interval |
# || || o :unselected: Consolidation cycles 3-5 |
# || || . Days 1-28: 15 mcg/m2/day . Days 29-42: 14-day treatment-free interval |
# |||
# || || || :unselected: o Continued therapy cycles 6-9 . Days 1-28: 15 mcg/m2/day |
# || || Days 29-84: 56-day treatment-free interval || |
#
#
# # VI. Product Availability
#
# Single-dose vial for reconstitution: 35 mcg
#
# VII. References
#
# <!-- PageNumber="Page 3 of 4" -->
# <figure>
#
# ![](figures/3)
#
# <!-- FigureContent="envolve Pharmacy Solutions TM" -->
#
# </figure>
#
#
# CLINICAL POLICY Blinatumomab
#
# 1\. Blincyto Prescribing Information. Thousand Oaks, CA: Amgen, Inc .; March 2018. Available at: http://pi.amgen.com/\~/media/amgen/repositorysites/pi-amgen- com/blincyto/blincyto\_pi\_hcp\_english.ashx. Accessed April 2018.
#
# 2\. National Comprehensive Cancer Network Drugs and Biologics Compendium. Available at nccn.org. Accessed April 2018.
#
# 3\. National Comprehensive Cancer Network Guidelines. Acute lymphoblastic leukemia; Version 1.2018. Available at nccn.org. Accessed April 2018.
#
# 4\. Clinical Pharmacology [database online]. Tampa, FL: Gold Standard, Inc .; 2018. Available at http://www.clinicalpharmacology-ip.com/.
#
# 5\. Gokbuget N, Dombret H, Bonifacio M, et al. Blinatumomab for minimal residual disease in adults with B-precursor acute lymphoblastic leukemia. Blood 2018; doi: https://doi.org/10.1182/blood-2017-08- 798322.
#
# 6\. Martinelli G, Boissel N, Chevallier P, et al. Complete hematologic and molecular response in adult patients with relapsed/refractory Philadelphia chromosome-positive B-precursor acute lymphoblastic leukemia following treatment with blinatumomab: results from a phase II, single-arm, multicenter study. J Clin Oncol. 2017 Jun 1; 35(16):1795-1802. doi: 10.1200/JCO.2016.69.3531. Epub 2017 Mar 29.
#
# 7\. Kim DY, Joo YD, Lim SN, et al. Nilotinib combined with multiagent chemotherapy for newly diagnosed Philadelphia-positive acute lymphoblastic leukemia. Blood 2015; 126: 746-756.
#
# 8\. Gambacorti-Passerini C, Kantarjian HM, Kim DW, et al. Longterm efficacy and safety of bosutinib in patients with advanced leukemia following resistance/ intolerance to imatinib and other tyrosine kinase inhibitors. Am J Hematol 2015; 90:755-768.
#
# | Reviews, Revisions, and Approvals | Date | P&T Approval Date |
# | - | - | - |
# | Policy created. | 05.08.18 | 08.18 |
#
#
# ## Important Reminder
#
# This clinical policy has been developed by appropriately experienced and licensed health care professionals based on a review and consideration of currently available generally accepted standards of medical practice; peer-reviewed medical literature; government agency/program approval status; evidence-based guidelines and positions of leading national health professional organizations; views of physicians practicing in relevant clinical areas affected by this clinical policy; and other available clinical information.
#
# This Clinical Policy is not intended to dictate to providers how to practice medicine, nor does it constitute a contract or guarantee regarding payment or results. Providers are expected to exercise professional medical judgment in providing the most appropriate care, and are solely responsible for the medical advice and treatment of members.
#
# This policy is the property of Envolve Pharmacy Solutions. Unauthorized copying, use, and distribution of this Policy or any information contained herein is strictly prohibited. By accessing this policy, you agree to be bound by the foregoing terms and conditions, in addition to the Site Use Agreement for Health Plans associated with Envolve Pharmacy Solutions.
#
# 2018 Envolve Pharmacy Solutions. All rights reserved. All materials are exclusively owned by Envolve Pharmacy Solutions and are protected by United States copyright law and international copyright law. No part of this publication may be reproduced, copied, modified, distributed, displayed, stored in a retrieval system, transmitted in any form or by any means, or otherwise published without the prior written permission of Envolve Pharmacy Solutions. You may not alter or remove any trademark, copyright or other notice contained herein.
#
# <!-- PageNumber="Page 4 of 4" -->
#
#
# ---
#
# **Instructions:**
#
# - Conduct a thorough analysis by comparing each piece of provided information against the corresponding policy criteria.
# - Extract all necessary information from both the policy text and the provided data.
# - Use a detailed comparison to evaluate how the request aligns with the policy requirements.
# - Base your decision solely on the provided information and policy text.
# - Do not include personal opinions or make assumptions beyond the given data.
#
# ---
#
# **Output Format:**
#
# **Prior Auth AI Determination**
#
# [Approved / Denied / Needs More Information]
#
# **Rationale**
#
# **Summary of Findings**
#
# - Briefly summarize how the request aligns with the policy criteria.
#
# **Detailed Analysis**
#
# **Policy Criteria Assessment**
#
# - Criterion 1: [State the criterion]
#   - Assessment: Fully Met / Partially Met / Not Met
#   - Evidence: Cite specific information from the patient or physician details.
#   - Policy Reference: Cite relevant sections from the policy text.
# - Criterion 2: [State the criterion]
#   - Assessment: Fully Met / Partially Met / Not Met
#   - Evidence: ...
#   - Policy Reference: ...
#   - (Continue for all relevant criteria)
#
# **Missing Information (if applicable)**
#
# - Information Needed: Specify what is missing.
# - Reason: Explain why this information is necessary according to the policy.
#
# ---
#
# **Note:**
#
# - Ensure that all conclusions are based solely on the provided information and policy text.
# - Do not make assumptions beyond what is given.
# - Provide clear and concise justifications for each assessment. (run.py:run:93)
# 2024-12-28 12:55:16,906 - autoDetermination - MainProcess - INFO     Using o1 model for final determination for TEST-003b... (run.py:run:118)
# 2024-12-28 12:55:16,909 - micro - MainProcess - INFO     Function generate_chat_response_o1 started at 2024-12-28 12:55:16 (aoai_helper.py:generate_chat_response_o1:264)
# 2024-12-28 12:55:16,910 - micro - MainProcess - INFO     Sending request to Azure OpenAI at 2024-12-28 12:55:16 (aoai_helper.py:generate_chat_response_o1:272)
# 2024-12-28 12:55:57,194 - micro - MainProcess - INFO     Model_used: o1-preview-2024-09-12 (aoai_helper.py:generate_chat_response_o1:296)
# 2024-12-28 12:55:57,196 - micro - MainProcess - INFO     Function generate_chat_response_o1 finished at 2024-12-28 12:55:57 (Duration: 40.29 seconds) (aoai_helper.py:generate_chat_response_o1:305)
# 2024-12-28 12:55:57,199 - autoDetermination - MainProcess - INFO
# Final Determination:
# **Prior Auth AI Determination**
#
# Denied
#
# **Rationale**
#
# Based on the provided clinical information and the policy criteria, the request for Blinatumomab (Blincyto) is denied. The patient does not meet all the required criteria outlined in the policy. Specifically, the patient has Philadelphia chromosome-positive (Ph+) relapsed or refractory B-cell precursor acute lymphoblastic leukemia (B-ALL) but has not demonstrated intolerance or refractoriness to at least one second-generation or later tyrosine kinase inhibitor (TKI) as required by the policy.
#
# **Summary of Findings**
#
# - **Met Criteria:**
#   - Diagnosis of B-cell precursor acute lymphoblastic leukemia (B-ALL).
#   - Prescribed by a pediatric hematologist and oncologist.
#   - Requested dose does not exceed 28 mcg/day.
# - **Unmet Criterion:**
#   - No documented intolerance or refractoriness to at least one second-generation or later TKI (Sprycel®, Tasigna®, Bosulif®, Iclusig®) for Ph+ disease.
#
# **Detailed Analysis**
#
# **Policy Criteria Assessment**
#
# - **Criterion 1:** **Diagnosis of B-cell precursor acute lymphoblastic leukemia (B-ALL)**
#   - **Assessment:** Fully Met
#   - **Evidence:** The patient is diagnosed with B-cell precursor acute lymphoblastic leukemia (B-ALL), including relapsed or refractory B-ALL.
#   - **Policy Reference:** I.A.1
#
# - **Criterion 2:** **Prescribed by or in consultation with an oncologist or hematologist**
#   - **Assessment:** Fully Met
#   - **Evidence:** The prescribing physician, Dr. Oncoso, specializes in Pediatric Hematology and Oncology.
#   - **Policy Reference:** I.A.2
#
# - **Criterion 3:** **Requested as treatment for:**
#   - **b. Relapsed or refractory B-ALL:**
#     - **ii. Philadelphia chromosome-positive (Ph+) disease and intolerant or refractory to at least one second-generation or later tyrosine kinase inhibitor (TKI; Sprycel®, Tasigna®, Bosulif®, Iclusig®)**
#   - **Assessment:** **Not Met**
#   - **Evidence:**
#     - The patient has Ph+ relapsed or refractory B-ALL.
#     - The patient has been treated with Imatinib, a first-generation TKI.
#     - There is no documentation of intolerance or refractoriness to at least one second-generation or later TKI (Sprycel®, Tasigna®, Bosulif®, Iclusig®).
#   - **Policy Reference:** I.A.3.b.ii
#
# - **Criterion 4:** **Dose does not exceed 28 mcg/day**
#   - **Assessment:** Fully Met
#   - **Evidence:** The requested dosage is 28 mcg/day.
#   - **Policy Reference:** I.A.4
#
# **Missing Information**
#
# - **Information Needed:** Documentation of intolerance or refractoriness to at least one second-generation or later TKI (Sprycel®, Tasigna®, Bosulif®, Iclusig®).
# - **Reason:** According to policy criterion I.A.3.b.ii, for Ph+ relapsed or refractory B-ALL, the patient must be intolerant or refractory to at least one second-generation or later TKI to qualify for Blinatumomab coverage.
#
# ---
#
# **Note:**
#
# - The request is denied because the patient does not meet all the required policy criteria.
# - If additional information becomes available demonstrating the patient's intolerance or refractoriness to a second-generation or later TKI, the request may be reconsidered.
# - All conclusions are based solely on the provided information and the policy text. (run.py:run:176)
# 2024-12-28 12:55:57,204 - PAProcessing - MainProcess - DEBUG    Data logged for case 'TEST-003b' at step 'llm_determination'. (run.py:log_output:377)
# 2024-12-28 12:55:57,210 - PAProcessing - MainProcess - INFO     Cleaned up temporary directory: C:\Users\pablosal\AppData\Local\Temp\tmpcdhprq12 (run.py:cleanup_temp_dir:414)
# 2024-12-28 12:55:58,658 - PAProcessing - MainProcess - INFO     Results stored in Cosmos DB for caseId TEST-003b (run.py:store_output:397)
# 2024-12-28 12:55:58,662 - PAProcessing - MainProcess - INFO     PAprocessing completed for TEST-003b. Execution time: 76.94 seconds. (run.py:run:602)

# %%
pa_pipeline.results
# Out:
# {'TEST-003b': {'raw_uploaded_files': ['https://storageaeastusfactory.blob.core.windows.net/pre-auth-policies/pa_proccesing_runs/TEST-003b/raw_uploaded_files/003_b (note) .pdf',
#    'https://storageaeastusfactory.blob.core.windows.net/pre-auth-policies/pa_proccesing_runs/TEST-003b/raw_uploaded_files/003_b (labs) .pdf',
#    'https://storageaeastusfactory.blob.core.windows.net/pre-auth-policies/pa_proccesing_runs/TEST-003b/raw_uploaded_files/003_b (form).pdf'],
#   'processed_images': ['https://storageaeastusfactory.blob.core.windows.net/pre-auth-policies/pa_proccesing_runs/TEST-003b/processed_images/003_b (form)-page-1.png',
#    'https://storageaeastusfactory.blob.core.windows.net/pre-auth-policies/pa_proccesing_runs/TEST-003b/processed_images/003_b (form)-page-2.png'],
#   'ocr_ner_results': {'patient_info': {'patient_name': 'Lucas Little',
#     'patient_date_of_birth': '07/30/2017',
#     'patient_id': '345987',
#     'patient_address': '28 Dearborn St, Chicago, IL, 60602',
#     'patient_phone_number': '555-360-8746'},
#    'physician_info': {'physician_name': 'Dr. Oncoso',
#     'specialty': 'Pediatric Hematology and Oncology',
#     'physician_contact': {'office_phone': '555-324-7878',
#      'fax': '555-324-7877',
#      'office_address': '27 W State St, Chicago, IL 60601'}},
#    'clinical_info': {'diagnosis': 'B-cell precursor acute lymphoblastic leukemia (B-ALL), post-consolidation phase treatment; Philadelphia chromosome-positive B-cell precursor acute lymphoblastic leukemia (B-ALL); relapsed or refractory B-ALL',
#     'icd_10_code': 'C91.00',
#     'prior_treatments_and_results': 'Induction Phase: Vincristine (weekly), Dexamethasone (daily for 28 days), L-asparaginase (alternate days), Daunorubicin (single dose during first week), Imatinib (daily throughout induction phase); Consolidation Phase: Methotrexate (high-dose, weekly), Mercaptopurine (daily oral), Vincristine (biweekly), Cyclophosphamide (third week), Doxorubicin (final week), Imatinib (daily throughout consolidation); Initial Proposed Maintenance Phase: Methotrexate (weekly), Mercaptopurine (daily oral), Vincristine (every 4 weeks), Imatinib (daily), Intrathecal Methotrexate (every 2-3 months)',
#     'specific_drugs_taken_and_failures': 'Imatinib: Administered daily throughout induction and consolidation phases; Methotrexate: High-dose, weekly; Mercaptopurine: Daily oral administration; Vincristine: Biweekly; Cyclophosphamide: Given during the third week; Doxorubicin: Administered during the final week of consolidation',
#     'alternative_drugs_required': 'Not provided',
#     'relevant_lab_results_or_imaging': 'White Blood Cell Count (WBC): 4,500 - 10,000 cells/µL; Neutrophils: 40%; Lymphocytes: 20%; Monocytes: 2%; Eosinophils: 1%; Basophils: 0%; Hemoglobin (Hgb): 11.5 g/dL; Hematocrit (Hct): 35%; Platelet Count: 150,000 cells/µL; Bone Marrow Biopsy (10/4/24): >90% blasts, relapsed or refractory B-ALL; Bone Marrow Biopsy (3/29/24): 85% lymphoblasts, Philadelphia chromosome-positive (Ph+)',
#     'symptom_severity_and_impact': 'Fatigue, mild fatigue and decreased energy, no recent fevers',
#     'prognosis_and_risk_if_not_approved': 'Risk of disease progression and worsening symptoms if treatment is not approved',
#     'clinical_rationale_for_urgency': 'Urgent need to prevent disease progression and manage relapsed or refractory B-ALL',
#     'treatment_request': {'name_of_medication_or_procedure': 'Blinatumomab',
#      'code_of_medication_or_procedure': 'Not provided',
#      'dosage': '28 mcg/day',
#      'duration': 'Induction cycle 1: Days 1-28: 28 mcg/day; Based on clinical response, up to 6 months',
#      'rationale': 'To manage relapsed or refractory B-ALL and prevent disease progression',
#      'presumed_eligibility': 'Patient has tried and failed previous treatments including Imatinib and standard chemotherapy regimen'}}},
#   'agenticrag_results': {'query': 'Prior authorization policy for Blinatumomab for B-cell precursor acute lymphoblastic leukemia (B-ALL). Related terms: Philadelphia chromosome-positive B-cell precursor acute lymphoblastic leukemia, Ph+ B-ALL, relapsed B-ALL, refractory B-ALL, post-consolidation phase treatment, CD19-targeted therapy, BiTE (bispecific T-cell engager) therapy. Dosage details: 28 mcg/day, induction cycle 1: Days 1-28: 28 mcg/day, with potential treatment duration up to 6 months based on clinical response. Rationale: Management of relapsed or refractory B-ALL and prevention of disease progression.',
#    'policies': ['https://storageaeastusfactory.blob.core.windows.net/pre-auth-policies/policies_ocr/003.pdf'],
#    'evaluation': {'policies': ['https://storageaeastusfactory.blob.core.windows.net/pre-auth-policies/policies_ocr/003.pdf'],
#     'reasoning': ["Content from https://storageaeastusfactory.blob.core.windows.net/pre-auth-policies/policies_ocr/003.pdf was approved because it explicitly mentioned prior authorization criteria for Blinatumomab (Blincyto) in treating B-cell precursor acute lymphoblastic leukemia (B-ALL), including both relapsed and refractory cases, and provided detailed dosage information matching the user's query."],
#     'retry': False}},
#   'pa_determination_results': "**Prior Auth AI Determination**\n\nDenied\n\n**Rationale**\n\nBased on the provided clinical information and the policy criteria, the request for Blinatumomab (Blincyto) is denied. The patient does not meet all the required criteria outlined in the policy. Specifically, the patient has Philadelphia chromosome-positive (Ph+) relapsed or refractory B-cell precursor acute lymphoblastic leukemia (B-ALL) but has not demonstrated intolerance or refractoriness to at least one second-generation or later tyrosine kinase inhibitor (TKI) as required by the policy.\n\n**Summary of Findings**\n\n- **Met Criteria:**\n  - Diagnosis of B-cell precursor acute lymphoblastic leukemia (B-ALL).\n  - Prescribed by a pediatric hematologist and oncologist.\n  - Requested dose does not exceed 28 mcg/day.\n- **Unmet Criterion:**\n  - No documented intolerance or refractoriness to at least one second-generation or later TKI (Sprycel®, Tasigna®, Bosulif®, Iclusig®) for Ph+ disease.\n\n**Detailed Analysis**\n\n**Policy Criteria Assessment**\n\n- **Criterion 1:** **Diagnosis of B-cell precursor acute lymphoblastic leukemia (B-ALL)**\n  - **Assessment:** Fully Met\n  - **Evidence:** The patient is diagnosed with B-cell precursor acute lymphoblastic leukemia (B-ALL), including relapsed or refractory B-ALL.\n  - **Policy Reference:** I.A.1\n\n- **Criterion 2:** **Prescribed by or in consultation with an oncologist or hematologist**\n  - **Assessment:** Fully Met\n  - **Evidence:** The prescribing physician, Dr. Oncoso, specializes in Pediatric Hematology and Oncology.\n  - **Policy Reference:** I.A.2\n\n- **Criterion 3:** **Requested as treatment for:**\n  - **b. Relapsed or refractory B-ALL:**\n    - **ii. Philadelphia chromosome-positive (Ph+) disease and intolerant or refractory to at least one second-generation or later tyrosine kinase inhibitor (TKI; Sprycel®, Tasigna®, Bosulif®, Iclusig®)**\n  - **Assessment:** **Not Met**\n  - **Evidence:**\n    - The patient has Ph+ relapsed or refractory B-ALL.\n    - The patient has been treated with Imatinib, a first-generation TKI.\n    - There is no documentation of intolerance or refractoriness to at least one second-generation or later TKI (Sprycel®, Tasigna®, Bosulif®, Iclusig®).\n  - **Policy Reference:** I.A.3.b.ii\n\n- **Criterion 4:** **Dose does not exceed 28 mcg/day**\n  - **Assessment:** Fully Met\n  - **Evidence:** The requested dosage is 28 mcg/day.\n  - **Policy Reference:** I.A.4\n\n**Missing Information**\n\n- **Information Needed:** Documentation of intolerance or refractoriness to at least one second-generation or later TKI (Sprycel®, Tasigna®, Bosulif®, Iclusig®).\n- **Reason:** According to policy criterion I.A.3.b.ii, for Ph+ relapsed or refractory B-ALL, the patient must be intolerant or refractory to at least one second-generation or later TKI to qualify for Blinatumomab coverage.\n\n---\n\n**Note:**\n\n- The request is denied because the patient does not meet all the required policy criteria.\n- If additional information becomes available demonstrating the patient's intolerance or refractoriness to a second-generation or later TKI, the request may be reconsidered.\n- All conclusions are based solely on the provided information and the policy text."}}

# %% [markdown]
# ## Query from Cosmos DB

# %%
from src.cosmosdb.cosmosmongodb_helper import CosmosDBMongoCoreManager

session_State = CosmosDBMongoCoreManager(
    connection_string=os.getenv("AZURE_COSMOS_CONNECTION_STRING"),
    database_name=os.getenv("AZURE_COSMOS_DB_DATABASE_NAME"),
    collection_name=os.getenv("AZURE_COSMOS_DB_COLLECTION_NAME"),
)
# Out:
# C:\Users\pablosal\Desktop\gbb-ai-hls-factory-prior-auth\src\cosmosdb\cosmosmongodb_helper.py:31: UserWarning: You appear to be connected to a CosmosDB cluster. For more information regarding feature compatibility and support please visit https://www.mongodb.com/supportability/cosmosdb
#   self.client = pymongo.MongoClient(connection_string)

# %%
query = {"caseId": CASE_ID}
document = session_State.read_document(query)

# %%
document
# Out:
# {'_id': ObjectId('67703e84e2ca41c818bad60f'),
#  'caseId': 'TEST-003b',
#  'raw_uploaded_files': ['https://storageaeastusfactory.blob.core.windows.net/pre-auth-policies/pa_proccesing_runs/TEST-003b/raw_uploaded_files/003_b (note) .pdf',
#   'https://storageaeastusfactory.blob.core.windows.net/pre-auth-policies/pa_proccesing_runs/TEST-003b/raw_uploaded_files/003_b (labs) .pdf',
#   'https://storageaeastusfactory.blob.core.windows.net/pre-auth-policies/pa_proccesing_runs/TEST-003b/raw_uploaded_files/003_b (form).pdf'],
#  'processed_images': ['https://storageaeastusfactory.blob.core.windows.net/pre-auth-policies/pa_proccesing_runs/TEST-003b/processed_images/003_b (form)-page-1.png',
#   'https://storageaeastusfactory.blob.core.windows.net/pre-auth-policies/pa_proccesing_runs/TEST-003b/processed_images/003_b (form)-page-2.png'],
#  'ocr_ner_results': {'patient_info': {'patient_name': 'Lucas Little',
#    'patient_date_of_birth': '07/30/2017',
#    'patient_id': '345987',
#    'patient_address': '28 Dearborn St, Chicago, IL, 60602',
#    'patient_phone_number': '555-360-8746'},
#   'physician_info': {'physician_name': 'Dr. Oncoso',
#    'specialty': 'Pediatric Hematology and Oncology',
#    'physician_contact': {'office_phone': '555-324-7878',
#     'fax': '555-324-7877',
#     'office_address': '27 W State St, Chicago, IL 60601'}},
#   'clinical_info': {'diagnosis': 'B-cell precursor acute lymphoblastic leukemia (B-ALL), post-consolidation phase treatment; Philadelphia chromosome-positive B-cell precursor acute lymphoblastic leukemia (B-ALL); relapsed or refractory B-ALL',
#    'icd_10_code': 'C91.00',
#    'prior_treatments_and_results': 'Induction Phase: Vincristine (weekly), Dexamethasone (daily for 28 days), L-asparaginase (alternate days), Daunorubicin (single dose during first week), Imatinib (daily throughout induction phase); Consolidation Phase: Methotrexate (high-dose, weekly), Mercaptopurine (daily oral), Vincristine (biweekly), Cyclophosphamide (third week), Doxorubicin (final week), Imatinib (daily throughout consolidation); Initial Proposed Maintenance Phase: Methotrexate (weekly), Mercaptopurine (daily oral), Vincristine (every 4 weeks), Imatinib (daily), Intrathecal Methotrexate (every 2-3 months)',
#    'specific_drugs_taken_and_failures': 'Imatinib: Administered daily throughout induction and consolidation phases; Methotrexate: High-dose, weekly; Mercaptopurine: Daily oral administration; Vincristine: Biweekly; Cyclophosphamide: Given during the third week; Doxorubicin: Administered during the final week of consolidation',
#    'alternative_drugs_required': 'Not provided',
#    'relevant_lab_results_or_imaging': 'White Blood Cell Count (WBC): 4,500 - 10,000 cells/µL; Neutrophils: 40%; Lymphocytes: 20%; Monocytes: 2%; Eosinophils: 1%; Basophils: 0%; Hemoglobin (Hgb): 11.5 g/dL; Hematocrit (Hct): 35%; Platelet Count: 150,000 cells/µL; Bone Marrow Biopsy (10/4/24): >90% blasts, relapsed or refractory B-ALL; Bone Marrow Biopsy (3/29/24): 85% lymphoblasts, Philadelphia chromosome-positive (Ph+)',
#    'symptom_severity_and_impact': 'Fatigue, mild fatigue and decreased energy, no recent fevers',
#    'prognosis_and_risk_if_not_approved': 'Risk of disease progression and worsening symptoms if treatment is not approved',
#    'clinical_rationale_for_urgency': 'Urgent need to prevent disease progression and manage relapsed or refractory B-ALL',
#    'treatment_request': {'name_of_medication_or_procedure': 'Blinatumomab',
#     'code_of_medication_or_procedure': 'Not provided',
#     'dosage': '28 mcg/day',
#     'duration': 'Induction cycle 1: Days 1-28: 28 mcg/day; Based on clinical response, up to 6 months',
#     'rationale': 'To manage relapsed or refractory B-ALL and prevent disease progression',
#     'presumed_eligibility': 'Patient has tried and failed previous treatments including Imatinib and standard chemotherapy regimen'}}},
#  'agenticrag_results': {'query': 'Prior authorization policy for Blinatumomab for B-cell precursor acute lymphoblastic leukemia (B-ALL). Related terms: Philadelphia chromosome-positive B-cell precursor acute lymphoblastic leukemia, Ph+ B-ALL, relapsed B-ALL, refractory B-ALL, post-consolidation phase treatment, CD19-targeted therapy, BiTE (bispecific T-cell engager) therapy. Dosage details: 28 mcg/day, induction cycle 1: Days 1-28: 28 mcg/day, with potential treatment duration up to 6 months based on clinical response. Rationale: Management of relapsed or refractory B-ALL and prevention of disease progression.',
#   'policies': ['https://storageaeastusfactory.blob.core.windows.net/pre-auth-policies/policies_ocr/003.pdf'],
#   'evaluation': {'policies': ['https://storageaeastusfactory.blob.core.windows.net/pre-auth-policies/policies_ocr/003.pdf'],
#    'reasoning': ["Content from https://storageaeastusfactory.blob.core.windows.net/pre-auth-policies/policies_ocr/003.pdf was approved because it explicitly mentioned prior authorization criteria for Blinatumomab (Blincyto) in treating B-cell precursor acute lymphoblastic leukemia (B-ALL), including both relapsed and refractory cases, and provided detailed dosage information matching the user's query."],
#    'retry': False}},
#  'pa_determination_results': "**Prior Auth AI Determination**\n\nDenied\n\n**Rationale**\n\nBased on the provided clinical information and the policy criteria, the request for Blinatumomab (Blincyto) is denied. The patient does not meet all the required criteria outlined in the policy. Specifically, the patient has Philadelphia chromosome-positive (Ph+) relapsed or refractory B-cell precursor acute lymphoblastic leukemia (B-ALL) but has not demonstrated intolerance or refractoriness to at least one second-generation or later tyrosine kinase inhibitor (TKI) as required by the policy.\n\n**Summary of Findings**\n\n- **Met Criteria:**\n  - Diagnosis of B-cell precursor acute lymphoblastic leukemia (B-ALL).\n  - Prescribed by a pediatric hematologist and oncologist.\n  - Requested dose does not exceed 28 mcg/day.\n- **Unmet Criterion:**\n  - No documented intolerance or refractoriness to at least one second-generation or later TKI (Sprycel®, Tasigna®, Bosulif®, Iclusig®) for Ph+ disease.\n\n**Detailed Analysis**\n\n**Policy Criteria Assessment**\n\n- **Criterion 1:** **Diagnosis of B-cell precursor acute lymphoblastic leukemia (B-ALL)**\n  - **Assessment:** Fully Met\n  - **Evidence:** The patient is diagnosed with B-cell precursor acute lymphoblastic leukemia (B-ALL), including relapsed or refractory B-ALL.\n  - **Policy Reference:** I.A.1\n\n- **Criterion 2:** **Prescribed by or in consultation with an oncologist or hematologist**\n  - **Assessment:** Fully Met\n  - **Evidence:** The prescribing physician, Dr. Oncoso, specializes in Pediatric Hematology and Oncology.\n  - **Policy Reference:** I.A.2\n\n- **Criterion 3:** **Requested as treatment for:**\n  - **b. Relapsed or refractory B-ALL:**\n    - **ii. Philadelphia chromosome-positive (Ph+) disease and intolerant or refractory to at least one second-generation or later tyrosine kinase inhibitor (TKI; Sprycel®, Tasigna®, Bosulif®, Iclusig®)**\n  - **Assessment:** **Not Met**\n  - **Evidence:**\n    - The patient has Ph+ relapsed or refractory B-ALL.\n    - The patient has been treated with Imatinib, a first-generation TKI.\n    - There is no documentation of intolerance or refractoriness to at least one second-generation or later TKI (Sprycel®, Tasigna®, Bosulif®, Iclusig®).\n  - **Policy Reference:** I.A.3.b.ii\n\n- **Criterion 4:** **Dose does not exceed 28 mcg/day**\n  - **Assessment:** Fully Met\n  - **Evidence:** The requested dosage is 28 mcg/day.\n  - **Policy Reference:** I.A.4\n\n**Missing Information**\n\n- **Information Needed:** Documentation of intolerance or refractoriness to at least one second-generation or later TKI (Sprycel®, Tasigna®, Bosulif®, Iclusig®).\n- **Reason:** According to policy criterion I.A.3.b.ii, for Ph+ relapsed or refractory B-ALL, the patient must be intolerant or refractory to at least one second-generation or later TKI to qualify for Blinatumomab coverage.\n\n---\n\n**Note:**\n\n- The request is denied because the patient does not meet all the required policy criteria.\n- If additional information becomes available demonstrating the patient's intolerance or refractoriness to a second-generation or later TKI, the request may be reconsidered.\n- All conclusions are based solely on the provided information and the policy text."}

# %%
print(document['pa_determination_results'])
# Out:
# **Prior Auth AI Determination**
#
# Denied
#
# **Rationale**
#
# Based on the provided clinical information and the policy criteria, the request for Blinatumomab (Blincyto) is denied. The patient does not meet all the required criteria outlined in the policy. Specifically, the patient has Philadelphia chromosome-positive (Ph+) relapsed or refractory B-cell precursor acute lymphoblastic leukemia (B-ALL) but has not demonstrated intolerance or refractoriness to at least one second-generation or later tyrosine kinase inhibitor (TKI) as required by the policy.
#
# **Summary of Findings**
#
# - **Met Criteria:**
#   - Diagnosis of B-cell precursor acute lymphoblastic leukemia (B-ALL).
#   - Prescribed by a pediatric hematologist and oncologist.
#   - Requested dose does not exceed 28 mcg/day.
# - **Unmet Criterion:**
#   - No documented intolerance or refractoriness to at least one second-generation or later TKI (Sprycel®, Tasigna®, Bosulif®, Iclusig®) for Ph+ disease.
#
# **Detailed Analysis**
#
# **Policy Criteria Assessment**
#
# - **Criterion 1:** **Diagnosis of B-cell precursor acute lymphoblastic leukemia (B-ALL)**
#   - **Assessment:** Fully Met
#   - **Evidence:** The patient is diagnosed with B-cell precursor acute lymphoblastic leukemia (B-ALL), including relapsed or refractory B-ALL.
#   - **Policy Reference:** I.A.1
#
# - **Criterion 2:** **Prescribed by or in consultation with an oncologist or hematologist**
#   - **Assessment:** Fully Met
#   - **Evidence:** The prescribing physician, Dr. Oncoso, specializes in Pediatric Hematology and Oncology.
#   - **Policy Reference:** I.A.2
#
# - **Criterion 3:** **Requested as treatment for:**
#   - **b. Relapsed or refractory B-ALL:**
#     - **ii. Philadelphia chromosome-positive (Ph+) disease and intolerant or refractory to at least one second-generation or later tyrosine kinase inhibitor (TKI; Sprycel®, Tasigna®, Bosulif®, Iclusig®)**
#   - **Assessment:** **Not Met**
#   - **Evidence:**
#     - The patient has Ph+ relapsed or refractory B-ALL.
#     - The patient has been treated with Imatinib, a first-generation TKI.
#     - There is no documentation of intolerance or refractoriness to at least one second-generation or later TKI (Sprycel®, Tasigna®, Bosulif®, Iclusig®).
#   - **Policy Reference:** I.A.3.b.ii
#
# - **Criterion 4:** **Dose does not exceed 28 mcg/day**
#   - **Assessment:** Fully Met
#   - **Evidence:** The requested dosage is 28 mcg/day.
#   - **Policy Reference:** I.A.4
#
# **Missing Information**
#
# - **Information Needed:** Documentation of intolerance or refractoriness to at least one second-generation or later TKI (Sprycel®, Tasigna®, Bosulif®, Iclusig®).
# - **Reason:** According to policy criterion I.A.3.b.ii, for Ph+ relapsed or refractory B-ALL, the patient must be intolerant or refractory to at least one second-generation or later TKI to qualify for Blinatumomab coverage.
#
# ---
#
# **Note:**
#
# - The request is denied because the patient does not meet all the required policy criteria.
# - If additional information becomes available demonstrating the patient's intolerance or refractoriness to a second-generation or later TKI, the request may be reconsidered.
# - All conclusions are based solely on the provided information and the policy text.
